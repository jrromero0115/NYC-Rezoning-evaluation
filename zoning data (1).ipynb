# %%
pip install geopandas
# Out:
# Collecting geopandas
#   Downloading geopandas-0.9.0-py2.py3-none-any.whl (994 kB)
#      |████████████████████████████████| 994 kB 5.2 MB/s
# Collecting pyproj>=2.2.0
#   Downloading pyproj-3.1.0-cp37-cp37m-manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 18.5 MB/s
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.1.5)
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.20-cp37-cp37m-manylinux1_x86_64.whl (15.4 MB)
#      |████████████████████████████████| 15.4 MB 36 kB/s
# Requirement already satisfied: shapely>=1.6 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.7.1)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (2021.5.30)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (21.2.0)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.15.0)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (57.2.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->geopandas) (2018.9)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->geopandas) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->geopandas) (2.8.1)
# Installing collected packages: munch, cligj, click-plugins, pyproj, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.8.20 geopandas-0.9.0 munch-2.5.0 pyproj-3.1.0

# %%
pip install rtree
# Out:
# Collecting rtree
#   Downloading Rtree-0.9.7-cp37-cp37m-manylinux2010_x86_64.whl (994 kB)
#      |████████████████████████████████| 994 kB 4.2 MB/s
# Installing collected packages: rtree
# Successfully installed rtree-0.9.7

# %%
import pandas as pd

import geopandas as gpd
import pydot
import cartopy
import libarchive
import matplotlib.pyplot as plt
from datetime import datetime

# %%
nyco = gpd.read_file("/content/drive/MyDrive/Rezoning/nyco.shp")
nylh = gpd.read_file("/content/drive/MyDrive/Rezoning/nylh.shp")
nysp = gpd.read_file("/content/drive/MyDrive/Rezoning/nysp.shp")
nysp_sd = gpd.read_file("/content/drive/MyDrive/Rezoning/nysp_sd.shp")
nyzd = gpd.read_file("/content/drive/MyDrive/Rezoning/nyzd.shp")
nyzma = gpd.read_file("/content/drive/MyDrive/Rezoning/nyzma.shp")

# %%
import rtree

# %%
taxlot =pd.read_csv('/content/drive/MyDrive/Rezoning/taxlot/NY_ZoningTaxLotDB20210630.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (5,6,7,8,9,10,11,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
mergedZone= gpd.read_file("/content/drive/MyDrive/Rezoning/merged nyczone.shp")

# %%
boundaryDB= gpd.read_file("/content/drive/MyDrive/Rezoning/downtownBrooklyn boundary.shp")

# %%
zoneDB= gpd.read_file("/content/drive/MyDrive/Rezoning/clipedDB.shp")

# %%
amendment=zoneDB.loc[(zoneDB['layer']== 'nyzma')]
amendment.columns
# Out:
# Index(['OVERLAY', 'Shape_Leng', 'Shape_Area', 'LHNAME', 'LHLBL', 'SDNAME',
#        'SDLBL', 'SPNAME', 'SPLBL', 'SUBDIST', 'SUB_AREA_N', 'SUBDIST_LB',
#        'SUBAREA_LB', 'SUBAREA_OT', 'ZONEDIST', 'EFFECTIVE', 'STATUS',
#        'ULURPNO', 'LUCATS', 'PROJECT_NA', 'layer', 'path', 'geometry'],
#       dtype='object')

# %%
amendment=amendment[['EFFECTIVE', 'STATUS','ULURPNO', 'LUCATS', 'PROJECT_NA','Shape_Area','geometry']].sort_values(by=['EFFECTIVE'])

# %%
amendment= amendment.dropna(how='any',axis=0)

# %%
amendment['EFFECTIVE']=pd.to_datetime(amendment['EFFECTIVE'])

# %%
amendment['YEAR']=pd.DatetimeIndex(amendment['EFFECTIVE']).year

# %%
amendment_clean= amendment.loc[(amendment['YEAR']> 2003)]

# %%
def mapPlot (data,title2, column):
  fig, ax = plt.subplots(figsize = (10,10))
  plt.title(title2)
  data.plot(column = column,ax=ax,legend=True)
  boundaryDB.geometry.boundary.plot(color=None,edgecolor='k',linewidth = 2,ax=ax)

# %%
mapPlot(amendment_clean,'AmendmentsByYears', 'YEAR')

# %%
def mapPlot (data,title2, column):
  fig, ax = plt.subplots(figsize = (10,10))
  plt.title(title2)
  data.plot(column = column,ax=ax,legend=True)
  plt.legend([data[column]],bbox_to_anchor=(1.04,1), loc="upper left")
  boundaryDB.geometry.boundary.plot(color=None,edgecolor='k',linewidth = 2,ax=ax)

# %%
  fig, ax = plt.subplots(figsize = (20,20))
  plt.title('amendment_clean')
  plt.legend([amendment_clean['PROJECT_NA']],bbox_to_anchor=(1.5,1), loc='upper left')
  amendment_clean.plot(column = 'PROJECT_NA',ax=ax, legend=True)  
  boundaryDB.geometry.boundary.plot(color=None,edgecolor='k',linewidth = 2,ax=ax)

# %%
nyco.head()
# Out:
#   OVERLAY  ...                                           geometry
# 0    C1-1  ...  POLYGON ((1034212.932 247414.680, 1034211.762 ...
# 1    C1-1  ...  POLYGON ((1034487.326 247708.733, 1034483.963 ...
# 2    C1-1  ...  POLYGON ((1026514.576 249190.367, 1026542.980 ...
# 3    C1-1  ...  POLYGON ((1026229.896 249164.442, 1026243.201 ...
# 4    C1-1  ...  POLYGON ((1034471.777 247402.689, 1034470.740 ...
#
# [5 rows x 4 columns]

# %%
dic = {'nysp':'SDNAME','nylh':'LHNAME','nyco':'OVERLAY','nysp_sd':'SPNAME'}

# %%
for i in dic:
  fig, ax = plt.subplots(figsize = (10,10))
  plt.title(i)
  zoneDB.loc[(zoneDB['layer']== i)].plot(column = dic[i],ax=ax,legend=True)
  boundaryDB.geometry.boundary.plot(color=None,edgecolor='k',linewidth = 2,ax=ax)

# %%
nyzd_cliped= gpd.clip(nyzd,boundaryDB)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-83-d924a7650068> in <module>()
# ----> 1 nyzd_cliped= gpd.clip(nyzd,boundaryDB)
#
# /usr/local/lib/python3.7/dist-packages/geopandas/tools/clip.py in clip(gdf, mask, keep_geom_type)
#     166
#     167     if poly_idx.any():
# --> 168         poly_gdf = _clip_line_poly(gdf[poly_idx], poly)
#     169     else:
#     170         poly_gdf = None
#
# /usr/local/lib/python3.7/dist-packages/geopandas/tools/clip.py in _clip_line_poly(gdf, poly)
#      62         that intersects with poly.
#      63     """
# ---> 64     gdf_sub = gdf.iloc[gdf.sindex.query(poly, predicate="intersects")]
#      65
#      66     # Clip the data with the polygon
#
# /usr/local/lib/python3.7/dist-packages/geopandas/base.py in sindex(self)
#    2628                [2]])
#    2629         """
# -> 2630         return self.geometry.values.sindex
#    2631
#    2632     @property
#
# /usr/local/lib/python3.7/dist-packages/geopandas/array.py in sindex(self)
#     307         See Also
#     308         ---------
# --> 309         GeoDataFrame.has_sindex
#     310
#     311         Returns
#
# /usr/local/lib/python3.7/dist-packages/geopandas/sindex.py in _get_sindex_class()
#      20         return RTreeIndex
#      21     raise ImportError(
# ---> 22         "Spatial indexes require either `rtree` or `pygeos`. "
#      23         "See installation instructions at https://geopandas.org/install.html"
#      24     )
#
# ImportError: Spatial indexes require either `rtree` or `pygeos`. See installation instructions at https://geopandas.org/install.html
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
  fig, ax = plt.subplots(figsize = (10,10))
  plt.title(i)
  nyzd.plot(column = 'ZONEDIST',ax=ax,legend=True)
  boundaryDB.geometry.boundary.plot(color=None,edgecolor='k',linewidth = 2,ax=ax)

# %%
taxlot.loc[(taxlot['Borough Code']==3)]
# Out:
#         Borough Code  Tax Block  ...  Zoning Map Number  Zoning Map Code
# 90                 3        133  ...                12D              NaN
# 91                 3        422  ...                16C              NaN
# 92                 3        423  ...                16C              NaN
# 93                 3        428  ...                16C              NaN
# 94                 3        766  ...                22A              NaN
# ...              ...        ...  ...                ...              ...
# 858422             3       8235  ...                23C              NaN
# 858423             3       8235  ...                23C              NaN
# 858424             3       8235  ...                23C              NaN
# 858431             3       8235  ...                23C              NaN
# 858435             3       8273  ...                23C              NaN
#
# [276991 rows x 16 columns]
